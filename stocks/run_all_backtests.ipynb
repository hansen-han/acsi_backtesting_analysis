# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import warnings
import pandas as pd
import yfinance as yf
from datetime import datetime, timedelta

# %%
today = datetime.now()
todays_date = today.strftime("%Y-%m-%d")

# %%
from stock_backtesting import get_stock_data
stock_data = get_stock_data(ticker="SPY")
stock_data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                       Datetime        Open        High         Low  \
# 0    2021-08-24 09:30:00-04:00  447.970001  448.375000  447.420013
# 1    2021-08-24 10:30:00-04:00  448.355011  448.459991  447.974792
# 2    2021-08-24 11:30:00-04:00  447.980011  448.079987  447.649994
# 3    2021-08-24 12:30:00-04:00  447.690002  448.089996  447.589996
# 4    2021-08-24 13:30:00-04:00  447.994995  448.399994  447.994995
# ...                        ...         ...         ...         ...
# 3488 2023-08-21 11:30:00-04:00  435.994995  436.950012  435.320007
# 3489 2023-08-21 12:30:00-04:00  436.910004  438.144989  436.589996
# 3490 2023-08-21 13:30:00-04:00  437.898987  438.690002  437.809998
# 3491 2023-08-21 14:30:00-04:00  438.359985  439.720001  438.239990
# 3492 2023-08-21 15:30:00-04:00  439.404999  440.109985  439.109985
#
#            Close   Adj Close    Volume                 timestamp       price  \
# 0     448.357300  448.357300   9739548 2021-08-24 09:30:00-04:00  447.970001
# 1     447.980011  447.980011   4113709 2021-08-24 10:30:00-04:00  448.355011
# 2     447.690002  447.690002   4028868 2021-08-24 11:30:00-04:00  447.980011
# 3     447.989990  447.989990   2865662 2021-08-24 12:30:00-04:00  447.690002
# 4     448.290009  448.290009   2764731 2021-08-24 13:30:00-04:00  447.994995
# ...          ...         ...       ...                       ...         ...
# 3488  436.910004  436.910004   7102069 2023-08-21 11:30:00-04:00  435.994995
# 3489  437.899994  437.899994   7203314 2023-08-21 12:30:00-04:00  436.910004
# 3490  438.348511  438.348511   7856755 2023-08-21 13:30:00-04:00  437.898987
# 3491  439.399994  439.399994   7484517 2023-08-21 14:30:00-04:00  438.359985
# 3492  439.339996  439.339996  10868884 2023-08-21 15:30:00-04:00  439.404999
#
#       quarter
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 3488        9
# 3489        9
# 3490        9
# 3491        9
# 3492        9
#
# [3493 rows x 10 columns]

# %%
from stock_backtesting import run_multiple_backtests

#Run all the combinations we want to look at 
strategies = ["mean reversion", "simple moving average crossover"]
shorting_settings = [True, False]

for strategy in strategies:
    for shorting in shorting_settings:
        result_df = run_multiple_backtests(
            shorting_allowed=shorting,
            num_runs=100,
            fixed_fee=False,
            stock_df=stock_data,
            strategy=strategy
        )
        shorting_str = "shorting" if shorting else "no_shorting"
        filename = f"run_output/{strategy.replace(' ', '_')}_{shorting_str}_{todays_date}.csv"
        result_df.to_csv(filename)
# Out:
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
# /Users/hansenhan/asci_backtesting_analysis/stocks/stock_backtesting.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['timestamp'] = pd.to_datetime(sampled_data['timestamp'])
